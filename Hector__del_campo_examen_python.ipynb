# %% [markdown]
# <a href="https://colab.research.google.com/github/Martinfi3ld/CITIZENDATASCIENCE/blob/main/Hector__del_campo_examen_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
    # Código que puede causar una excepción
    file_handler = open('casos_confirmados.csv', 'r')
    for line in file_handler:
        print(line.strip())
    file_handler.close()
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 719201,guanajuato,FEMENINO,56,2020-07-07,1
# 719202,veracruz de ignacio de la llave,FEMENINO,38,2020-07-07,1
# 719203,distrito federal,MASCULINO,69,2020-07-07,1
# 719204,veracruz de ignacio de la llave,MASCULINO,31,2020-07-07,1
# 719205,oaxaca,FEMENINO,55,2020-07-07,1
# 719206,sonora,MASCULINO,40,2020-07-07,1
# 719207,sinaloa,MASCULINO,60,2020-07-06,1
# 719208,colima,FEMENINO,67,2020-07-07,1
# 719209,coahuila,FEMENINO,46,2020-07-07,1
# 719210,chihuahua,MASCULINO,40,2020-07-01,1
# 719211,nuevo león,MASCULINO,56,2020-07-14,1
# 719212,méxico,FEMENINO,42,2020-07-14,1
# 719213,méxico,FEMENINO,77,2020-07-14,1
# 719214,jalisco,MASCULINO,69,2020-07-13,1
# 719215,sonora,FEMENINO,23,2020-07-14,1
# 719216,tabasco,FEMENINO,50,2020-07-14,1
# 719217,quintana roo,FEMENINO,21,2020-07-14,1
# 719218,jalisco,FEMENINO,54,2020-07-14,1
# 719219,nuevo león,MASCULINO,32,2020-07-14,1
# 719220,sinaloa,MASCULINO,40,2020-07-14,1
# ...

# %%
 with open('casos_confirmados.csv', 'r') as file_handler:
        headers = file_handler.readline().strip().split(',')

        for line in file_handler:
            values = line.strip().split(',')
            print(f"Edad: {age}, Género: {sex}")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# Edad: 20, Género: FEMENINO
# ...

# %%
#Realiza los cálculos necesarios para conocer la edad promedio de los participantes y si hay más hombres o mujeres contagiados.

import pandas as pd
import numpy as np

df = pd.read_csv('casos_confirmados.csv')
Conteo_de_sexos = df['Sex'].value_counts()
Conteo_de_sexos
# Out:
# Sex
# MASCULINO    198358
# FEMENINO     172354
# Name: count, dtype: int64

# %%
#sacar conteo por sexo y poner edad promedio

Edad_promedio_por_sexo = df[['Sex','Age']].groupby('Sex').mean()
Edad_promedio_por_sexo
# Out:
#                  Age
# Sex
# FEMENINO   44.539639
# MASCULINO  45.998044

# %%
import seaborn as sns
import matplotlib.pyplot as plt

print('Cual es la edad promedio de los pacientes?  \n', Edad_promedio_por_sexo)
print()
print()
print('conteo de contagios por sexo: \n', Conteo_de_sexos)
print()
print()
print('Grafico de Contagios por Sexo')
sns.countplot(x='Sex', data=df)
plt.title('Contagios por sexo')
plt.xlabel('Sexo')
plt.ylabel('Contagios')
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                       textcoords='offset points')
plt.show()
# Out:
# Cual es la edad promedio de los pacientes?
#                   Age
# Sex
# FEMENINO   44.539639
# MASCULINO  45.998044
#
#
# conteo de contagios por sexo:
#  Sex
# MASCULINO    198358
# FEMENINO     172354
# Name: count, dtype: int64
#
#
# Grafico de Contagios por Sexo
